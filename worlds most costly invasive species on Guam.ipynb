# %% [markdown]
# # Status of the World's Most Costly Invasive Species on Guam
# [Aubrey Moore](mailto://aubreymoore@triton.uog.edu), University of Guam
#
# On March 21, 2021, Diagne et al. published an article entitled *Status of the World's Most Costly Invasive Species* in *Nature* [2]. In this article, they present a figure showing costs associated with ten of the most costly taxa, which includes seven insects, two mammals and one snake. Below, I have annotated their figure to indicate occurrence on Guam.
#
# **Figure 5 from Diagne et al. 2021 annotated by Aubrey Moore to show occurrence on Guam.**
#
# ![plot](5-annotated.png)
#
# **Fig. 5** The 10 costliest taxa from the most robust subset of the original database for both cumulative damage and management costs (in billions of 2017 US dollars) between 1970 and 2017. Mixed costs are cost estimates for which the specific monetary contribution of damage and management costs could not be disentangled from the reporting studies. Each bar represents a species or a complex of species (when different species were often considered simultaneously to provide cost estimates). Numbers below the bars indicate the number of cost estimates. This ranking illustrates the limits of the available data and the need for more thorough and standardized cost reports (Supplementary Discussion 1). All animal silhouettes were obtained from an open source platform (http://phylopic.org/). The silhouette of *Coptotermes* was created by Melissa Broussard.
#
# ## Annotations for Guam
# **GU** indicates that a taxon occurs on Guam determined using results from a search of the Global Biodiversity Information Facility database [1].
#
# ### Taxon Notes
#
# ***Aedes* spp.** x species of *Aedes* mosquitoes are currently on Guam [1]: A. guamensis, . A.aegyti was previously present, but this is one of the very few invasive species successfully eradicated from the island.
#
# ***Rattus* spp./*Mus* spp.** x species of rodents in these genera are currently on Guam:
#
# ***Felis catus*** GBIF contains no Guam records for this species. However, domestic and feral house cats are abundant on Guam.
#
# ***Coptotermes formosanus***
#
# ***Solenopsis invicta***
#
# ***Boiga irregularis***
#
# ***Anthonomus grandis***
#
# ***Lymantria dispar***
#
# ***Apis mellifera scutellata***
#
# ***Cochliomyia hominivorax***
#
# ## References
#
# [1] GBIF.org (4 April 2021) GBIF Occurrence Download https://doi.org/10.15468/dl.7atvrc
#
# [2] Diagne, Christophe, Boris Leroy, Anne-Charlotte VaissiÃ¨re, Rodolphe E. Gozlan, David Roiz, Ivan JariÄ‡, Jean-Michel Salles, Corey J. A. Bradshaw, and Franck Courchamp. â€œHigh and Rising Economic Costs of Biological Invasions Worldwide.â€ Nature, March 31, 2021, 1â€“6. https://doi.org/10.1038/s41586-021-03405-6.
#
#
#
# [readonly link](https://www.nature.com/articles/s41586-021-03405-6.epdf?sharing_token=gzAIS34eQrFgpg6755NR9NRgN0jAjWel9jnR3ZoTv0N-hjc_skiWnPirhq64a5g9G8FoO2H0zrGElFjOf25pdvBarBVWKpyVc4jJeaw5SUrONw3ngCedft-uNLJQKdH_zr8n3z-cnlZHS9Q5JV34q9vMLLF7xtWbZPnfYRMSH3s%3D)
#
# ![plot](5.jpg)
#
# **Fig. 5** The 10 costliest taxa from the most robust subset of the original database for both cumulative damage and management costs (in billions of 2017 US dollars) between 1970 and 2017. Mixed costs are cost estimates for which the specific monetary contribution of damage and management costs could not be disentangled from the reporting studies. Each bar represents a species or a complex of species (when different species were often considered simultaneously to provide cost estimates). Numbers below the bars indicate the number of cost estimates. This ranking illustrates the limits of the available data and the need for more thorough and standardized cost reports (Supplementary Discussion 1). All animal silhouettes were obtained from an open source platform (http://phylopic.org/). The silhouette of *Coptotermes* was created by Melissa Broussard.
#
# ## Annotations for Guam
# **GU** indicates that a taxon exists on Guam.
#
# ### Taxon Notes
#
# ***Aedes* spp.** x species of *Aedes* mosquitoes are currently on Guam [1]: A. guamensis, . A.aegyti has been collected on Guam, but this is one of the very few invasive species successfully eradicated from the island.
#
# ***Rattus* spp./*Mus* spp.** x species of rodents in these genera are currently on Guam:
#
# ***Felis catus*** GBIF contains no Guam records for this species. However, domestic and feral house cats are abundant on Guam.
#
# ***Coptotermes formosanus***
#
# ***Solenopsis invicta***
#
# ***Boiga irregularis***
#
# ***Anthonomus grandis***
#
# ***Lymantria dispar***
#
# ***Apis mellifera scutellata***
#
# ***Cochliomyia hominivorax***
#
# ## References
#
# [1] GBIF.org (4 April 2021) GBIF Occurrence Download https://doi.org/10.15468/dl.7atvrc
#
# [2] Diagne, Christophe, Boris Leroy, Anne-Charlotte VaissiÃ¨re, Rodolphe E. Gozlan, David Roiz, Ivan JariÄ‡, Jean-Michel Salles, Corey J. A. Bradshaw, and Franck Courchamp. â€œHigh and Rising Economic Costs of Biological Invasions Worldwide.â€ Nature, March 31, 2021, 1â€“6. https://doi.org/10.1038/s41586-021-03405-6.

# %%
from pygbif import species as species
from pygbif import occurrences as occ
import requests
import json
import getpass
import pandas as pd

# %%
gbif_password = getpass.getpass('Enter your GBIF password:')
# Out:
# Enter your GBIF password:········

# %%
# Use pygbif to get numerical keys for the taxa listed in the plot

names = [
    'Aedes', 
    'Rattus', 
    'Mus', 
    'Felis catus',
    'Coptotermes formosanus', 
    'Solenopsis invicta', 
    'Boiga irregularis', 
    'Anthonomus grandis',
    'Lymantria dispar',
    'Apis mellifera scutellata',
    'Cochliomyia hominivorax'
]
taxon_keys= []
for name in names:
    taxon = species.name_backbone(name)
    print(name)
    print(taxon)
    print()
    taxon_keys.append(taxon['usageKey'])
# Out:
# Aedes
# {'usageKey': 7924646, 'scientificName': 'Aedes Meigen, 1818', 'canonicalName': 'Aedes', 'rank': 'GENUS', 'status': 'ACCEPTED', 'confidence': 94, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Diptera', 'family': 'Culicidae', 'genus': 'Aedes', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 811, 'familyKey': 3346, 'genusKey': 7924646, 'synonym': False, 'class': 'Insecta'}
#
# Rattus
# {'usageKey': 2439223, 'scientificName': 'Rattus Fischer, 1803', 'canonicalName': 'Rattus', 'rank': 'GENUS', 'status': 'ACCEPTED', 'confidence': 92, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Chordata', 'order': 'Rodentia', 'family': 'Muridae', 'genus': 'Rattus', 'kingdomKey': 1, 'phylumKey': 44, 'classKey': 359, 'orderKey': 1459, 'familyKey': 5510, 'genusKey': 2439223, 'synonym': False, 'class': 'Mammalia'}
#
# Mus
# {'usageKey': 9800657, 'scientificName': 'Mus Linnaeus, 1758', 'canonicalName': 'Mus', 'rank': 'GENUS', 'status': 'ACCEPTED', 'confidence': 92, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Chordata', 'order': 'Rodentia', 'family': 'Muridae', 'genus': 'Mus', 'kingdomKey': 1, 'phylumKey': 44, 'classKey': 359, 'orderKey': 1459, 'familyKey': 5510, 'genusKey': 9800657, 'synonym': False, 'class': 'Mammalia'}
#
# Felis catus
# {'usageKey': 2435035, 'scientificName': 'Felis catus Linnaeus, 1758', 'canonicalName': 'Felis catus', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Chordata', 'order': 'Carnivora', 'family': 'Felidae', 'genus': 'Felis', 'species': 'Felis catus', 'kingdomKey': 1, 'phylumKey': 44, 'classKey': 359, 'orderKey': 732, 'familyKey': 9703, 'genusKey': 2435022, 'speciesKey': 2435035, 'synonym': False, 'class': 'Mammalia'}
#
# Coptotermes formosanus
# {'usageKey': 2007383, 'scientificName': 'Coptotermes formosanus Shiraki, 1909', 'canonicalName': 'Coptotermes formosanus', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Blattodea', 'family': 'Rhinotermitidae', 'genus': 'Coptotermes', 'species': 'Coptotermes formosanus', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 800, 'familyKey': 4354, 'genusKey': 2007379, 'speciesKey': 2007383, 'synonym': False, 'class': 'Insecta'}
#
# Solenopsis invicta
# {'usageKey': 5035230, 'scientificName': 'Solenopsis invicta Buren, 1972', 'canonicalName': 'Solenopsis invicta', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Hymenoptera', 'family': 'Formicidae', 'genus': 'Solenopsis', 'species': 'Solenopsis invicta', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 1457, 'familyKey': 4342, 'genusKey': 9107211, 'speciesKey': 5035230, 'synonym': False, 'class': 'Insecta'}
#
# Boiga irregularis
# {'usageKey': 2457884, 'scientificName': 'Boiga irregularis (Bechstein, 1802)', 'canonicalName': 'Boiga irregularis', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Chordata', 'order': 'Squamata', 'family': 'Colubridae', 'genus': 'Boiga', 'species': 'Boiga irregularis', 'kingdomKey': 1, 'phylumKey': 44, 'classKey': 358, 'orderKey': 715, 'familyKey': 6172, 'genusKey': 2457835, 'speciesKey': 2457884, 'synonym': False, 'class': 'Reptilia'}
#
# Anthonomus grandis
# {'usageKey': 5013559, 'scientificName': 'Anthonomus grandis Boheman, 1843', 'canonicalName': 'Anthonomus grandis', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Coleoptera', 'family': 'Curculionidae', 'genus': 'Anthonomus', 'species': 'Anthonomus grandis', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 1470, 'familyKey': 4239, 'genusKey': 9223407, 'speciesKey': 5013559, 'synonym': False, 'class': 'Insecta'}
#
# Lymantria dispar
# {'usageKey': 1820406, 'scientificName': 'Lymantria dispar (Linnaeus, 1758)', 'canonicalName': 'Lymantria dispar', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Lepidoptera', 'family': 'Erebidae', 'genus': 'Lymantria', 'species': 'Lymantria dispar', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 797, 'familyKey': 4532185, 'genusKey': 1820270, 'speciesKey': 1820406, 'synonym': False, 'class': 'Insecta'}
#
# Apis mellifera scutellata
# {'usageKey': 11044201, 'acceptedUsageKey': 1341976, 'scientificName': 'Apis mellifera scutellata Lepeletier, 1836', 'canonicalName': 'Apis mellifera scutellata', 'rank': 'SUBSPECIES', 'status': 'SYNONYM', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Hymenoptera', 'family': 'Apidae', 'genus': 'Apis', 'species': 'Apis mellifera', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 1457, 'familyKey': 4334, 'genusKey': 1334757, 'speciesKey': 1341976, 'synonym': True, 'class': 'Insecta'}
#
# Cochliomyia hominivorax
# {'usageKey': 1502208, 'scientificName': 'Cochliomyia hominivorax Coquerel, 1858', 'canonicalName': 'Cochliomyia hominivorax', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Animalia', 'phylum': 'Arthropoda', 'order': 'Diptera', 'family': 'Calliphoridae', 'genus': 'Cochliomyia', 'species': 'Cochliomyia hominivorax', 'kingdomKey': 1, 'phylumKey': 54, 'classKey': 216, 'orderKey': 811, 'familyKey': 3335, 'genusKey': 1502207, 'speciesKey': 1502208, 'synonym': False, 'class': 'Insecta'}

# %%
# Prepare parameters for a GBIF download request

headers = {
    'Content-Type': 'application/json',
}

data = {}
data['creator'] = 'aubreymoore'
data['notificationAddresses'] = ['aubreymoore@guam.net']
data['sendNotification'] = True
data['format'] = 'SPECIES_LIST'

data['predicate'] = {}
data['predicate']['type'] = 'and'
data['predicate']['predicates'] = []
data['predicate']['predicates'].append({'type':'equals', 'key':'COUNTRY', 'value':'GU'})
data['predicate']['predicates'].append({'type':'in', 'key':'TAXON_KEY', 'values':taxon_keys})
data = json.dumps(data)
data
# Out:
# '{"creator": "aubreymoore", "notificationAddresses": ["aubreymoore@guam.net"], "sendNotification": true, "format": "SPECIES_LIST", "predicate": {"type": "and", "predicates": [{"type": "equals", "key": "COUNTRY", "value": "GU"}, {"type": "in", "key": "TAXON_KEY", "values": [7924646, 2439223, 9800657, 2435035, 2007383, 5035230, 2457884, 5013559, 1820406, 11044201, 1502208]}]}}'

# %%
# Request a GBIF download. A DOI will be assigned and email will arrive when the download file has been compiled.

response = requests.post('https://api.gbif.org/v1/occurrence/download/request',
                         headers=headers, 
                         data=data,
                         auth=('aubreymoore@guam.net', gbif_password))
if response.ok:
    print(response.content)
    print('You will be notified by email when your download is available.')
else:
    print('Something went wrong.')
# Out:
# b'0239999-200613084148143'
# You will be notified by email when your download is available.

# %%
df = pd.read_csv('0239999-200613084148143.csv', sep='\t')
df = df.sort_values(by=['scientificName'])
df
# Out:
#     taxonKey                                   scientificName  \
# 0    7924646                               Aedes Meigen, 1818
# 13   1651430                     Aedes albopictus Skuse, 1894
# 1    1651842            Aedes guamensis Farner & Bohart, 1944
# 12   1651765                      Aedes hensilli Farner, 1945
# 8    1652386                        Aedes pandani Stone, 1939
# 3    2457884              Boiga irregularis (Bechstein, 1802)
# 6    9800657                               Mus Linnaeus, 1758
# 10   4264890          Mus musculus castaneus Waterhouse, 1843
# 4    4264886  Mus musculus domesticus Schwarz & Schwarz, 1943
# 11   2439223                             Rattus Fischer, 1803
# 9    2439244                     Rattus exulans (Peale, 1848)
# 7    2439261             Rattus norvegicus (Berkenhout, 1769)
# 5    2439270                   Rattus rattus (Linnaeus, 1758)
# 2    2439262                 Rattus tanezumi (Temminck, 1845)
#
#     acceptedTaxonKey                           acceptedScientificName  \
# 0            7924646                               Aedes Meigen, 1818
# 13           1651430                     Aedes albopictus Skuse, 1894
# 1            1651842            Aedes guamensis Farner & Bohart, 1944
# 12           1651765                      Aedes hensilli Farner, 1945
# 8            1652386                        Aedes pandani Stone, 1939
# 3            2457884              Boiga irregularis (Bechstein, 1802)
# 6            9800657                               Mus Linnaeus, 1758
# 10           4264890          Mus musculus castaneus Waterhouse, 1843
# 4            4264886  Mus musculus domesticus Schwarz & Schwarz, 1943
# 11           2439223                             Rattus Fischer, 1803
# 9            2439244                     Rattus exulans (Peale, 1848)
# 7            2439261             Rattus norvegicus (Berkenhout, 1769)
# 5            2439270                   Rattus rattus (Linnaeus, 1758)
# 2            2439262                 Rattus tanezumi (Temminck, 1845)
#
#     numberOfOccurrences   taxonRank taxonomicStatus   kingdom  kingdomKey  \
# 0                     1       GENUS        ACCEPTED  Animalia           1
# 13                    2     SPECIES        ACCEPTED  Animalia           1
# 1                     5     SPECIES        ACCEPTED  Animalia           1
# 12                    2     SPECIES        ACCEPTED  Animalia           1
# 8                    40     SPECIES        ACCEPTED  Animalia           1
# 3                  1025     SPECIES        ACCEPTED  Animalia           1
# 6                    12       GENUS        ACCEPTED  Animalia           1
# 10                   57  SUBSPECIES        ACCEPTED  Animalia           1
# 4                     1  SUBSPECIES        ACCEPTED  Animalia           1
# 11                    2       GENUS        ACCEPTED  Animalia           1
# 9                    80     SPECIES        ACCEPTED  Animalia           1
# 7                    10     SPECIES        ACCEPTED  Animalia           1
# 5                     5     SPECIES        ACCEPTED  Animalia           1
# 2                   184     SPECIES        ACCEPTED  Animalia           1
#
#         phylum  ...  classKey     order  orderKey      family  familyKey  \
# 0   Arthropoda  ...       216   Diptera       811   Culicidae       3346
# 13  Arthropoda  ...       216   Diptera       811   Culicidae       3346
# 1   Arthropoda  ...       216   Diptera       811   Culicidae       3346
# 12  Arthropoda  ...       216   Diptera       811   Culicidae       3346
# 8   Arthropoda  ...       216   Diptera       811   Culicidae       3346
# 3     Chordata  ...       358  Squamata       715  Colubridae       6172
# 6     Chordata  ...       359  Rodentia      1459     Muridae       5510
# 10    Chordata  ...       359  Rodentia      1459     Muridae       5510
# 4     Chordata  ...       359  Rodentia      1459     Muridae       5510
# 11    Chordata  ...       359  Rodentia      1459     Muridae       5510
# 9     Chordata  ...       359  Rodentia      1459     Muridae       5510
# 7     Chordata  ...       359  Rodentia      1459     Muridae       5510
# 5     Chordata  ...       359  Rodentia      1459     Muridae       5510
# 2     Chordata  ...       359  Rodentia      1459     Muridae       5510
#
#      genus  genusKey            species  speciesKey iucnRedListCategory
# 0    Aedes   7924646                NaN         NaN                 NaN
# 13   Aedes   7924646   Aedes albopictus   1651430.0                 NaN
# 1    Aedes   7924646    Aedes guamensis   1651842.0                 NaN
# 12   Aedes   7924646     Aedes hensilli   1651765.0                 NaN
# 8    Aedes   7924646      Aedes pandani   1652386.0                 NaN
# 3    Boiga   2457835  Boiga irregularis   2457884.0                  LC
# 6      Mus   9800657                NaN         NaN                 NaN
# 10     Mus   9800657       Mus musculus   7429082.0                 NaN
# 4      Mus   9800657       Mus musculus   7429082.0                 NaN
# 11  Rattus   2439223                NaN         NaN                 NaN
# 9   Rattus   2439223     Rattus exulans   2439244.0                  LC
# 7   Rattus   2439223  Rattus norvegicus   2439261.0                  LC
# 5   Rattus   2439223      Rattus rattus   2439270.0                  LC
# 2   Rattus   2439223    Rattus tanezumi   2439262.0                  LC
#
# [14 rows x 22 columns]
